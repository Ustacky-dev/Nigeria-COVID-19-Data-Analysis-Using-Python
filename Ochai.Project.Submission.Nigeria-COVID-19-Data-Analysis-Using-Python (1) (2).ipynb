# %% [markdown]
# # Task 1 - Data Collection
# Here you will obtain the required data for the analysis. As described in the project instructions, you will perform a web scrap to obtain data from the NCDC website, import data from the JoHn Hopkins repository, and import the provided external data.

# %% [markdown]
# # A - NCDC Website scrap
# Website - https://covid19.ncdc.gov.ng/

# %%
# Importing all libraries
import os
os.chdir('C:\\Users\\OCHAI ODEH\\Downloads\\Nigeriadata')
import requests
import numpy as np
import urllib.request
import pandas as pd
import csv
from bs4 import BeautifulSoup
import seaborn as sns
sns.set_style("darkgrid")
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')  
import warnings
warnings.filterwarnings('ignore')

# %%
# checking response of server to get url request

url = 'https://covid19.ncdc.gov.ng'
status_code = requests.get(url)
status_code
# Out:
# <Response [200]>

# %%
# Reading NCDC data from url to a DataFrame object.
url = 'https://covid19.ncdc.gov.ng'
html = requests.get(url).content
df_list = pd.read_html(html)

#Saving the data from link to object nig_covid_cases
ncdcdata = df_list[-1]
print(ncdcdata)
ncdcdata.to_csv('ncdcdata.csv')
# Out:
#    States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0            Lagos                        103145                            2
# 1              FCT                         29161                          120
# 2           Rivers                         17755                          180
# 3           Kaduna                         11487                           20
# 4              Oyo                         10328                            2
# 5          Plateau                         10309                           27
# 6              Edo                          7821                          102
# 7             Ogun                          5810                           11
# 8            Delta                          5653                          371
# 9             Kano                          5186                           50
# 10            Ondo                          5173                          315
# 11       Akwa Ibom                          4973                           22
# 12           Kwara                          4680                          441
# 13            Osun                          3311                           29
# 14           Gombe                          3310                            6
# 15           Enugu                          2952                           13
# 16         Anambra                          2825                           46
# 17        Nasarawa                          2777                          393
# 18             Imo                          2655                            7
# 19           Ekiti                          2456                           37
# 20         Katsina                          2418                            0
# 21            Abia                          2239                           13
# 22           Benue                          2129                          340
# 23          Ebonyi                          2064                           28
# 24          Bauchi                          1990                           18
# 25           Borno                          1629                            5
# 26          Taraba                          1473                           62
# 27         Bayelsa                          1363                           10
# 28         Adamawa                          1203                           68
# 29           Niger                          1181                          163
# 30     Cross River                           877                            4
# 31          Sokoto                           822                            0
# 32          Jigawa                           669                            2
# 33            Yobe                           638                            4
# 34           Kebbi                           480                           10
# 35         Zamfara                           375                            0
# 36            Kogi                             5                            0
#
#     No. Discharged  No. of Deaths
# 0           102372            771
# 1            28792            249
# 2            17420            155
# 3            11378             89
# 4            10124            202
# 5            10207             75
# 6             7398            321
# 7             5717             82
# 8             5170            112
# 9             5009            127
# 10            4749            109
# 11            4907             44
# 12            4175             64
# 13            3190             92
# 14            3238             66
# 15            2910             29
# 16            2760             19
# 17            2345             39
# 18            2590             58
# 19            2391             28
# 20            2381             37
# 21            2192             34
# 22            1764             25
# 23            2004             32
# 24            1948             24
# 25            1580             44
# 26            1377             34
# 27            1325             28
# 28            1103             32
# 29             998             20
# 30             848             25
# 31             794             28
# 32             649             18
# 33             625              9
# 34             454             16
# 35             366              9
# 36               3              2

# %%
ncdcdata.head()
# Out:
#   States Affected  No. of Cases (Lab Confirmed)  No. of Cases (on admission)  \
# 0           Lagos                        103145                            2
# 1             FCT                         29161                          120
# 2          Rivers                         17755                          180
# 3          Kaduna                         11487                           20
# 4             Oyo                         10328                            2
#
#    No. Discharged  No. of Deaths
# 0          102372            771
# 1           28792            249
# 2           17420            155
# 3           11378             89
# 4           10124            202

# %% [markdown]
# # B - John Hopkins Data Repository
# Here you will obtain data from the John Hopkins repository. Your task here involves saving the data from the GitHub repo link to DataFrame for further analysis. Find the links below.
#
# Global Daily Confirmed Cases - Click Here Global Daily Recovered Cases - Click Here Global Daily Death Cases - Click Here

# %%
#Saving the data from John Hopkin's repository's link into a DataFrame object

confirmed_global= pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
covid19_recovered_global = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
covid19_deaths_global = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')

# %%
JH_confirmed_global=confirmed_global
JH_deaths_global=covid19_deaths_global
JH_recovered_global=covid19_recovered_global

# %%
#Reading some of the data from John Hopkin's repository
JH_deaths_global.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  8/21/22  8/22/22  8/23/22  \
# 0        0        0        0        0  ...     7762     7767     7768
# 1        0        0        0        0  ...     3576     3576     3577
# 2        0        0        0        0  ...     6878     6878     6878
# 3        0        0        0        0  ...      154      154      154
# 4        0        0        0        0  ...     1917     1917     1917
#
#    8/24/22  8/25/22  8/26/22  8/27/22  8/28/22  8/29/22  8/30/22
# 0     7769     7771     7771     7771     7777     7777     7777
# 1     3578     3579     3580     3581     3581     3581     3582
# 2     6878     6878     6878     6878     6878     6878     6878
# 3      154      154      154      154      154      154      154
# 4     1917     1917     1917     1917     1917     1917     1917
#
# [5 rows x 956 columns]

# %% [markdown]
# # External Data
#
# Save the external data to a DataFrame
# External Data includes but not limited to: covid_external.csv, Budget data.csv, RealGDP.csv

# %%
#Saving external data into dataframe objects
covid_external = pd.read_csv('covid_external.csv')
Budget_data = pd.read_csv('Budget data.csv')
RealGDP = pd.read_csv('RealGDP.csv')
ncdcdata = pd.read_csv('ncdcdata.csv')

# %%
#Reading some of the dataframes
ncdcdata.head()
# Out:
#    Unnamed: 0 States Affected  No. of Cases (Lab Confirmed)  \
# 0           0           Lagos                        103145
# 1           1             FCT                         29161
# 2           2          Rivers                         17755
# 3           3          Kaduna                         11487
# 4           4             Oyo                         10328
#
#    No. of Cases (on admission)  No. Discharged  No. of Deaths
# 0                            2          102372            771
# 1                          120           28792            249
# 2                          180           17420            155
# 3                           20           11378             89
# 4                            2           10124            202

# %%
covid_external.head()
# Out:
#       states         region  Population  Overall CCVI Index  Age  \
# 0        FCT  North Central     4865000                 0.3  0.0
# 1    Plateau  North Central     4766000                 0.4  0.5
# 2      Kwara  North Central     3524000                 0.3  0.4
# 3  Nassarawa  North Central     2783000                 0.1  0.3
# 4      Niger  North Central     6260000                 0.6  0.0
#
#    Epidemiological  Fragility  Health System  Population Density  \
# 0              0.9        0.4            0.6                 0.9
# 1              0.4        0.8            0.3                 0.3
# 2              0.3        0.2            0.4                 0.2
# 3              0.5        0.9            0.0                 0.1
# 4              0.6        0.3            0.7                 0.1
#
#    Socio-Economic   Transport Availability  Acute IHR
# 0             0.6                      0.2       0.79
# 1             0.5                      0.3       0.93
# 2             0.6                      0.7       0.93
# 3             0.6                      0.5       0.85
# 4             0.8                      0.8       0.84

# %%
Budget_data.head()
# Out:
#       states  Initial_budget (Bn)  Revised_budget (Bn)
# 0       Abia               136.60               102.70
# 1    Adamawa               183.30               139.31
# 2  Akwa-Ibom               597.73               366.00
# 3    Anambra               137.10               112.80
# 4     Bauchi               167.20               128.00

# %%
RealGDP.head()
# Out:
#    Year           Q1           Q2           Q3           Q4
# 0  2014  15438679.50  16084622.31  17479127.58  18150356.45
# 1  2015  16050601.38  16463341.91  17976234.59  18533752.07
# 2  2016  15943714.54  16218542.41  17555441.69  18213537.29
# 3  2017  15797965.83  16334719.27  17760228.17  18598067.07
# 4  2018  16096654.19  16580508.07  18081342.10  19041437.59

# %%
# Combining all 'external' dataframe objects provided using the merge() function on identical column
merged_t1 = pd.merge(covid_external, Budget_data, on= 'states', how ='outer', sort= True)

# %%
merged_t1.head()
# Out:
#       states      region  Population  Overall CCVI Index  Age  \
# 0       Abia  South East   4190000.0                 0.2  0.9
# 1    Adamawa  North East   4672000.0                 0.8  0.5
# 2  Akwa Ibom  South East   6093000.0                 0.7  0.8
# 3  Akwa-Ibom         NaN         NaN                 NaN  NaN
# 4    Anambra  South East   6050000.0                 0.6  0.9
#
#    Epidemiological  Fragility  Health System  Population Density  \
# 0              0.6        0.1            0.3                 0.9
# 1              0.6        0.9            0.7                 0.3
# 2              0.7        0.6            0.8                 0.8
# 3              NaN        NaN            NaN                 NaN
# 4              1.0        0.6            0.2                 1.0
#
#    Socio-Economic   Transport Availability  Acute IHR  Initial_budget (Bn)  \
# 0             0.2                      0.0       1.14               136.60
# 1             0.7                      0.6       0.94               183.30
# 2             0.5                      0.1       1.01                  NaN
# 3             NaN                      NaN        NaN               597.73
# 4             0.0                      0.1       1.08               137.10
#
#    Revised_budget (Bn)
# 0               102.70
# 1               139.31
# 2                  NaN
# 3               366.00
# 4               112.80

# %%
#Renaming of a column is necessary if web scrapped data from NCDC's link is to be merged with 'external' dataframe on identical column 'states'.
ncdcdata_rn = ncdcdata.rename(columns={'States Affected':'states'})

# %%
#Checking if Renaming was successful and type of data in imported data from NCDC's link.
ncdcdata_rn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    37 non-null     int64
#  1   states                        37 non-null     object
#  2   No. of Cases (Lab Confirmed)  37 non-null     int64
#  3   No. of Cases (on admission)   37 non-null     int64
#  4   No. Discharged                37 non-null     int64
#  5   No. of Deaths                 37 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.9+ KB

# %%
# All data values has to be converted to appropriate type (numeric). We use pd.to_numeric and apply the conversion.
ncdcdata_rndf = ncdcdata_rn[['No. of Cases (Lab Confirmed)', 'No. of Cases (on admission)', 'No. Discharged']].columns
ncdcdata_rn[ncdcdata_rndf] = ncdcdata_rn[ncdcdata_rndf].apply(pd.to_numeric,errors='coerce')

# %%
ncdcdata_rn.replace(',','', regex=True, inplace=True)

# %%
combined_df = merged_t1.append(RealGDP, ignore_index=True)

# %%
#Viewing the data
#Obtain basic information about the merged data using the head() and info() method.
combined_df.head()
# Out:
#       states      region  Population  Overall CCVI Index  Age  \
# 0       Abia  South East   4190000.0                 0.2  0.9
# 1    Adamawa  North East   4672000.0                 0.8  0.5
# 2  Akwa Ibom  South East   6093000.0                 0.7  0.8
# 3  Akwa-Ibom         NaN         NaN                 NaN  NaN
# 4    Anambra  South East   6050000.0                 0.6  0.9
#
#    Epidemiological  Fragility  Health System  Population Density  \
# 0              0.6        0.1            0.3                 0.9
# 1              0.6        0.9            0.7                 0.3
# 2              0.7        0.6            0.8                 0.8
# 3              NaN        NaN            NaN                 NaN
# 4              1.0        0.6            0.2                 1.0
#
#    Socio-Economic   Transport Availability  Acute IHR  Initial_budget (Bn)  \
# 0             0.2                      0.0       1.14               136.60
# 1             0.7                      0.6       0.94               183.30
# 2             0.5                      0.1       1.01                  NaN
# 3             NaN                      NaN        NaN               597.73
# 4             0.0                      0.1       1.08               137.10
#
#    Revised_budget (Bn)  Year  Q1  Q2  Q3  Q4
# 0               102.70   NaN NaN NaN NaN NaN
# 1               139.31   NaN NaN NaN NaN NaN
# 2                  NaN   NaN NaN NaN NaN NaN
# 3               366.00   NaN NaN NaN NaN NaN
# 4               112.80   NaN NaN NaN NaN NaN

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   states                   40 non-null     object
#  1   region                   37 non-null     object
#  2   Population               37 non-null     float64
#  3   Overall CCVI Index       37 non-null     float64
#  4   Age                      37 non-null     float64
#  5   Epidemiological          37 non-null     float64
#  6   Fragility                37 non-null     float64
#  7   Health System            37 non-null     float64
#  8   Population Density       37 non-null     float64
#  9   Socio-Economic           37 non-null     float64
#  10   Transport Availability  37 non-null     float64
#  11  Acute IHR                37 non-null     float64
#  12  Initial_budget (Bn)      37 non-null     float64
#  13  Revised_budget (Bn)      37 non-null     float64
#  14  Year                     7 non-null      float64
#  15  Q1                       7 non-null      float64
#  16  Q2                       7 non-null      float64
#  17  Q3                       7 non-null      float64
#  18  Q4                       7 non-null      float64
# dtypes: float64(17), object(2)
# memory usage: 7.1+ KB

# %%
Budget_data.nunique()
# Out:
# states                 37
# Initial_budget (Bn)    37
# Revised_budget (Bn)    37
# dtype: int64

# %%
covid_external.nunique()
# Out:
# states                     37
# region                      6
# Population                 37
# Overall CCVI Index         11
# Age                        11
# Epidemiological            11
# Fragility                  11
# Health System              11
# Population Density         11
# Socio-Economic             11
#  Transport Availability    11
# Acute IHR                  22
# dtype: int64

# %%
ncdcdata_rn.nunique()
# Out:
# Unnamed: 0                      37
# states                          37
# No. of Cases (Lab Confirmed)    37
# No. of Cases (on admission)     29
# No. Discharged                  37
# No. of Deaths                   30
# dtype: int64

# %% [markdown]
# Eight states have the same number of cases on admission.
# Seven states have the same number of death counts.
# All states have different counts for Cases Confirmed and Discharged.

# %%
RealGDP.nunique()
# Out:
# Year    7
# Q1      7
# Q2      7
# Q3      7
# Q4      7
# dtype: int64

# %% [markdown]
# # Task 2 - View the data
# Obtain basic information about the data using the head() and info() method.

# %% [markdown]
# # Viewing the separate external data and NCDC's data: Obtaining basic information about the data using the head() and info() method.

# %%
covid_external = pd.read_csv('covid_external.csv')
Budget_data = pd.read_csv('Budget data.csv')
RealGDP = pd.read_csv('RealGDP.csv')
covidnig = pd.read_csv('covidnig.csv')

# %%
covid_external.head()
# Out:
#       states         region  Population  Overall CCVI Index  Age  \
# 0        FCT  North Central     4865000                 0.3  0.0
# 1    Plateau  North Central     4766000                 0.4  0.5
# 2      Kwara  North Central     3524000                 0.3  0.4
# 3  Nassarawa  North Central     2783000                 0.1  0.3
# 4      Niger  North Central     6260000                 0.6  0.0
#
#    Epidemiological  Fragility  Health System  Population Density  \
# 0              0.9        0.4            0.6                 0.9
# 1              0.4        0.8            0.3                 0.3
# 2              0.3        0.2            0.4                 0.2
# 3              0.5        0.9            0.0                 0.1
# 4              0.6        0.3            0.7                 0.1
#
#    Socio-Economic   Transport Availability  Acute IHR
# 0             0.6                      0.2       0.79
# 1             0.5                      0.3       0.93
# 2             0.6                      0.7       0.93
# 3             0.6                      0.5       0.85
# 4             0.8                      0.8       0.84

# %%
covid_external.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   states                   37 non-null     object
#  1   region                   37 non-null     object
#  2   Population               37 non-null     int64
#  3   Overall CCVI Index       37 non-null     float64
#  4   Age                      37 non-null     float64
#  5   Epidemiological          37 non-null     float64
#  6   Fragility                37 non-null     float64
#  7   Health System            37 non-null     float64
#  8   Population Density       37 non-null     float64
#  9   Socio-Economic           37 non-null     float64
#  10   Transport Availability  37 non-null     float64
#  11  Acute IHR                37 non-null     float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 3.6+ KB

# %%
Budget_data.head()
# Out:
#       states  Initial_budget (Bn)  Revised_budget (Bn)
# 0       Abia               136.60               102.70
# 1    Adamawa               183.30               139.31
# 2  Akwa-Ibom               597.73               366.00
# 3    Anambra               137.10               112.80
# 4     Bauchi               167.20               128.00

# %%
Budget_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   states               37 non-null     object
#  1   Initial_budget (Bn)  37 non-null     float64
#  2   Revised_budget (Bn)  37 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1016.0+ bytes

# %%
RealGDP.head()
# Out:
#    Year           Q1           Q2           Q3           Q4
# 0  2014  15438679.50  16084622.31  17479127.58  18150356.45
# 1  2015  16050601.38  16463341.91  17976234.59  18533752.07
# 2  2016  15943714.54  16218542.41  17555441.69  18213537.29
# 3  2017  15797965.83  16334719.27  17760228.17  18598067.07
# 4  2018  16096654.19  16580508.07  18081342.10  19041437.59

# %%
RealGDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    7 non-null      int64
#  1   Q1      7 non-null      float64
#  2   Q2      7 non-null      float64
#  3   Q3      7 non-null      float64
#  4   Q4      7 non-null      float64
# dtypes: float64(4), int64(1)
# memory usage: 408.0 bytes

# %% [markdown]
# # Task 3 - Data Cleaning and Preparation

# %% [markdown]
# From the information obtained above, you will need to fix the data format.
# Examples:
#
# >Convert to appropriate data type.
# >Rename the columns of the scraped data.
# >Remove comma(,) in numerical data
# >Extract daily data for Nigeria from the Global daily cases data

# %% [markdown]
# TODO A - Clean the scraped data

# %%
#Data Cleaning and Preparation: Clean the scraped data
#Renaming columns of dataframe

# %%
#Renaming of columns of merged dataframe
combined_df.rename(columns = {'states':'State', 'region': 'Region', 'Initial_budget (Bn)': 'Initial Budget in Billion', 'Revised_budget (Bn)': 'Revised Budget in Billion', 'No. of Cases (Lab Confirmed)': 'Number of Lab Confirmed Cases', 'No. of Cases (on admission)':'Number of Cases on Admission', 'No. Discharged': 'Number of Cases Discharged', 'No. of Deaths': 'Number of Deaths', 'Q1': 'First Quarter', 'Q2': 'Second Quarter', 'Q3': 'Third Quarter', 'Q4':'Fourth Quarter'}, inplace = True)

# %%
# Checking if renamig is successful
combined_df.head()
# Out:
#        State      Region  Population  Overall CCVI Index  Age  \
# 0       Abia  South East   4190000.0                 0.2  0.9
# 1    Adamawa  North East   4672000.0                 0.8  0.5
# 2  Akwa Ibom  South East   6093000.0                 0.7  0.8
# 3  Akwa-Ibom         NaN         NaN                 NaN  NaN
# 4    Anambra  South East   6050000.0                 0.6  0.9
#
#    Epidemiological  Fragility  Health System  Population Density  \
# 0              0.6        0.1            0.3                 0.9
# 1              0.6        0.9            0.7                 0.3
# 2              0.7        0.6            0.8                 0.8
# 3              NaN        NaN            NaN                 NaN
# 4              1.0        0.6            0.2                 1.0
#
#    Socio-Economic   Transport Availability  Acute IHR  \
# 0             0.2                      0.0       1.14
# 1             0.7                      0.6       0.94
# 2             0.5                      0.1       1.01
# 3             NaN                      NaN        NaN
# 4             0.0                      0.1       1.08
#
#    Initial Budget in Billion  Revised Budget in Billion  Year  First Quarter  \
# 0                     136.60                     102.70   NaN            NaN
# 1                     183.30                     139.31   NaN            NaN
# 2                        NaN                        NaN   NaN            NaN
# 3                     597.73                     366.00   NaN            NaN
# 4                     137.10                     112.80   NaN            NaN
#
#    Second Quarter  Third Quarter  Fourth Quarter
# 0             NaN            NaN             NaN
# 1             NaN            NaN             NaN
# 2             NaN            NaN             NaN
# 3             NaN            NaN             NaN
# 4             NaN            NaN             NaN

# %%
# Checking data tyoes in columns of merged dataframe
combined_df.dtypes
# Out:
# State                         object
# Region                        object
# Population                   float64
# Overall CCVI Index           float64
# Age                          float64
# Epidemiological              float64
# Fragility                    float64
# Health System                float64
# Population Density           float64
# Socio-Economic               float64
#  Transport Availability      float64
# Acute IHR                    float64
# Initial Budget in Billion    float64
# Revised Budget in Billion    float64
# Year                         float64
# First Quarter                float64
# Second Quarter               float64
# Third Quarter                float64
# Fourth Quarter               float64
# dtype: object

# %%
JH_confirmed_global=confirmed_global
JH_deaths_global=covid19_deaths_global
JH_recovered_global=covid19_recovered_global

# %%
# Saved global data from John Hopkin's repository

# %%
# Saved global data from John Hopkin's repository
JH_confirmed_global=confirmed_global
JH_deaths_global=covid19_deaths_global
JH_recovered_global=covid19_recovered_global

# %%
#viewing basic information from John Hopkin's global data
JH_confirmed_global.head(n=205)
# Out:
#     Province/State Country/Region        Lat        Long  1/22/20  1/23/20  \
# 0              NaN    Afghanistan  33.939110   67.709953        0        0
# 1              NaN        Albania  41.153300   20.168300        0        0
# 2              NaN        Algeria  28.033900    1.659600        0        0
# 3              NaN        Andorra  42.506300    1.521800        0        0
# 4              NaN         Angola -11.202700   17.873900        0        0
# ..             ...            ...        ...         ...      ...      ...
# 200   Cook Islands    New Zealand -21.236700 -159.777700        0        0
# 201            NaN    New Zealand -40.900600  174.886000        0        0
# 202            NaN      Nicaragua  12.865416  -85.207229        0        0
# 203            NaN          Niger  17.607789    8.081666        0        0
# 204            NaN        Nigeria   9.082000    8.675300        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  8/21/22  8/22/22  8/23/22  \
# 0          0        0        0        0  ...   190643   191040   191247
# 1          0        0        0        0  ...   326077   326181   326787
# 2          0        0        0        0  ...   269805   269894   269971
# 3          0        0        0        0  ...    45975    45975    45975
# 4          0        0        0        0  ...   102636   102636   102636
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 200        0        0        0        0  ...     6265     6265     6265
# 201        0        0        0        0  ...  1718009  1721836  1725110
# 202        0        0        0        0  ...    14899    14899    14899
# 203        0        0        0        0  ...     9183     9203     9219
# 204        0        0        0        0  ...   262912   262912   263090
#
#      8/24/22  8/25/22  8/26/22  8/27/22  8/28/22  8/29/22  8/30/22
# 0     191585   191967   191967   191967   192463   192906   193004
# 1     327232   327607   327961   328299   328515   328571   329017
# 2     270043   270097   270145   270175   270194   270235   270272
# 3      46027    46027    46027    46027    46027    46027    46027
# 4     102636   102636   102636   102636   102636   102636   102636
# ..       ...      ...      ...      ...      ...      ...      ...
# 200     6265     6265     6265     6265     6265     6265     6265
# 201  1728018  1730494  1732765  1734157  1735902  1738492  1740840
# 202    14931    14931    14931    14931    14931    14931    14931
# 203     9250     9263     9263     9263     9263     9329     9329
# 204   263090   263322   263322   263407   263407   263407   263526
#
# [205 rows x 956 columns]

# %% [markdown]
# TODO B - Get a Pandas DataFrame for Daily Confirmed Cases in Nigeria. Columns are Date and Cases
#
# TODO C - Get a Pandas DataFrame for Daily Recovered Cases in Nigeria. Columns are Date and Cases
#
# TODO D - Get a Pandas DataFrame for Daily Death Cases in Nigeria. Columns are Date and Cases

# %%
#Getting a Pandas DataFrame for Daily Confirmed Cases in Nigeria. Columns are Date and Cases
# The data frames will be restructured to make data accessible and extractable. We restructure dataframe using pd.melt() and drop() method
JH_Daily_confirmed = pd.melt(JH_confirmed_global, id_vars=['Province/State','Country/Region','Lat', 'Long'], var_name='Date', value_name='Confirmed Cases')

# %%
# Still converting data tpe: Date column values is to be converted into standard Datetime format
JH_Daily_confirmed['Date'] =  pd.to_datetime(JH_Daily_confirmed['Date'])

# %%
#delete other columns aside date and country/region using the drop()method
JH_Daily_Confirmeddf= JH_Daily_confirmed.drop(['Province/State', 'Lat', 'Long'], axis=1, errors ='ignore')

# %%
#checking if the formatting of dataframe for global confirmed Cases is as expected
JH_Daily_Confirmeddf
# Out:
#               Country/Region       Date  Confirmed Cases
# 0                Afghanistan 2020-01-22                0
# 1                    Albania 2020-01-22                0
# 2                    Algeria 2020-01-22                0
# 3                    Andorra 2020-01-22                0
# 4                     Angola 2020-01-22                0
# ...                      ...        ...              ...
# 271315    West Bank and Gaza 2022-08-30           701739
# 271316  Winter Olympics 2022 2022-08-30              535
# 271317                 Yemen 2022-08-30            11926
# 271318                Zambia 2022-08-30           332822
# 271319              Zimbabwe 2022-08-30           256708
#
# [271320 rows x 3 columns]

# %%
#Applying formatting tools used for global confirmed cases to Dataframe of global recoveries and Deaths

JH_Daily_Recovery = pd.melt(JH_recovered_global, id_vars=['Province/State','Country/Region','Lat', 'Long'], var_name='Date', value_name='Recovered Cases')
JH_Daily_Recovery['Date'] =  pd.to_datetime(JH_Daily_Recovery['Date'])

# %%
JH_Daily_Recoverydf= JH_Daily_Recovery.drop(['Province/State', 'Lat', 'Long'], axis=1, errors ='ignore')

# %%
JH_Daily_Deaths = pd.melt(JH_deaths_global, id_vars=['Province/State','Country/Region','Lat', 'Long'], var_name='Date', value_name='Death Cases')
JH_Daily_Deaths['Date'] =  pd.to_datetime(JH_Daily_Deaths['Date'])

# %%
JH_Daily_Deathsdf= JH_Daily_Deaths.drop(['Province/State', 'Lat', 'Long'], axis=1, errors ='ignore')

# %%
#Getting a Pandas DataFrame for Daily Confirmed Cases in Nigeria. Columns are Date and Cases

# %%
Nigeria = JH_Daily_confirmed[JH_Daily_confirmed['Country/Region'] == 'Nigeria']

# %%
JH_Daily_Confirmed_Nigeriadf= Nigeria[['Date', 'Confirmed Cases']].reset_index(drop = True)

# %%
JH_Daily_Confirmed_Nigeriadf
# Out:
#           Date  Confirmed Cases
# 0   2020-01-22                0
# 1   2020-01-23                0
# 2   2020-01-24                0
# 3   2020-01-25                0
# 4   2020-01-26                0
# ..         ...              ...
# 947 2022-08-26           263322
# 948 2022-08-27           263407
# 949 2022-08-28           263407
# 950 2022-08-29           263407
# 951 2022-08-30           263526
#
# [952 rows x 2 columns]

# %%
JH_Daily_Confirmed_Nigeriadf.sum(axis=0)
# Out:
# Confirmed Cases    137490811
# dtype: int64

# %%
# Get a Pandas DataFrame for Daily Recovered Cases in Nigeria. Columns are Date and Cases

# %%
Nigeria = JH_Daily_Recovery[JH_Daily_Recovery['Country/Region'] == 'Nigeria']
JH_Daily_Recovery_Nigeriadf= Nigeria[['Date', 'Recovered Cases']].reset_index(drop = True)

# %%
JH_Daily_Recovery_Nigeriadf
# Out:
#           Date  Recovered Cases
# 0   2020-01-22                0
# 1   2020-01-23                0
# 2   2020-01-24                0
# 3   2020-01-25                0
# 4   2020-01-26                0
# ..         ...              ...
# 947 2022-08-26                0
# 948 2022-08-27                0
# 949 2022-08-28                0
# 950 2022-08-29                0
# 951 2022-08-30                0
#
# [952 rows x 2 columns]

# %%
#Get a Pandas DataFrame for Daily Death Cases in Nigeria. Columns are Date and Cases

# %%
# Getting total recovered cases in Nigeria upto Aug. 2022
JH_Daily_Recovery_Nigeriadf.sum(axis=0)
# Out:
# Recovered Cases    39492087
# dtype: int64

# %%
Nigeria = JH_Daily_Deaths[JH_Daily_Deaths['Country/Region'] == 'Nigeria']
JH_Daily_DeathsNigeriadf= Nigeria[['Date', 'Death Cases']].reset_index(drop = True)

# %%
# Getting total Deaths status in Nigeria upto Aug. 2022
JH_Daily_DeathsNigeriadf.sum(axis=0)
# Out:
# Death Cases    1799577
# dtype: int64

# %%
JH_Daily_DeathsNigeriadf
# Out:
#           Date  Death Cases
# 0   2020-01-22            0
# 1   2020-01-23            0
# 2   2020-01-24            0
# 3   2020-01-25            0
# 4   2020-01-26            0
# ..         ...          ...
# 947 2022-08-26         3148
# 948 2022-08-27         3148
# 949 2022-08-28         3148
# 950 2022-08-29         3148
# 951 2022-08-30         3148
#
# [952 rows x 2 columns]

# %% [markdown]
# # Task 4 - Analysis

# %% [markdown]
# Here you will perform some analyses on the datasets. You are welcome to communicate findings in charts and summary.
# We have included a few TODOs to help with your analysis. However, do not let this limit your approach, feel free to include more, and be sure to support your findings with chart and summary

# %% [markdown]
# TODO A - Generate a plot that shows the Top 10 states in terms of Confirmed Covid cases by Laboratory test

# %%
# To Generate a plot that shows the Top 10 states in terms of Confirmed Covid cases by Laboratory 
#First renaming columns from original dataframe fro link (data cleaning)
ncdcdata_rn
ncdcdata_rn.rename(columns = {'states': 'States Affected','No. of Cases (Lab Confirmed)': 'Number of Lab Confirmed Cases', 'No. of Cases (on admission)':'Number of Cases on Admission', 'No. Discharged': 'Number of Cases Discharged', 'No. of Deaths': 'Number of Deaths'}, inplace = True)

# %%
#Sorting top 10 states with highest lab confirmed cases by using df.sort_values()

ncdcdata_rn_lab10confirmed = ncdcdata_rn.sort_values('Number of Lab Confirmed Cases', ascending = False)
ncdcdata_rn_lab10confirmed = ncdcdata_rn_lab10confirmed.iloc[:10,]

# %%
#checking top 10 states
ncdcdata_rn_lab10confirmed
# Out:
#    Unnamed: 0 States Affected  Number of Lab Confirmed Cases  \
# 0           0           Lagos                         103145
# 1           1             FCT                          29161
# 2           2          Rivers                          17755
# 3           3          Kaduna                          11487
# 4           4             Oyo                          10328
# 5           5         Plateau                          10309
# 6           6             Edo                           7821
# 7           7            Ogun                           5810
# 8           8           Delta                           5653
# 9           9            Kano                           5186
#
#    Number of Cases on Admission  Number of Cases Discharged  Number of Deaths
# 0                             2                      102372               771
# 1                           120                       28792               249
# 2                           180                       17420               155
# 3                            20                       11378                89
# 4                             2                       10124               202
# 5                            27                       10207                75
# 6                           102                        7398               321
# 7                            11                        5717                82
# 8                           371                        5170               112
# 9                            50                        5009               127

# %%
# Plotting top 10 states with corresponding confirmed cases
Top_10_ncdc_cases = sns.barplot(x='Number of Lab Confirmed Cases', y='States Affected', data=ncdcdata_rn_lab10confirmed, color = 'blue').set_title('Top 10 covid cases in Nigerian States')

# %% [markdown]
# Lagos with the highest Confirmed covid case and Delta is with the lowest as at 30th August, 2022.

# %%
#Generating a plot that shows the Top 10 states in terms of Discharged Covid cases. Hint - Sort the values
ncdcdata_rn_10Discharged = ncdcdata_rn.sort_values('Number of Cases Discharged', ascending = False)
ncdcdata_rn_10Discharged = ncdcdata_rn_10Discharged.iloc[:10,]

# %% [markdown]
# TODO B - Generate a plot that shows the Top 10 states in terms of Discharged Covid cases. Hint - Sort the values

# %%
ncdc_disch_plot = sns.barplot(x='Number of Cases Discharged', y='States Affected', data=ncdcdata_rn_10Discharged, color = 'blue').set_title('Top 10 covid Discharges')

# %% [markdown]
# As at 30th August, 2022, Lagos shows the highest number of discharges is because it has a high population figure, highest number of confirmed cases and better health management system.

# %% [markdown]
# TODO D - Plot the top 10 Death cases

# %%
#Plotting the top 10 Death cases

# %%
#Generating a plot that shows the Top 10 states in terms of death cases. Hint - Sort the values
ncdcdata_rn_10Deaths = ncdcdata_rn.sort_values('Number of Deaths', ascending = False)
ncdcdata_rn_10Deaths = ncdcdata_rn_10Deaths.iloc[:10,]

# %%
ncdcdata_rnDeaths_plot = sns.barplot(x='Number of Deaths', y='States Affected', data=ncdcdata_rn_10Deaths, color = 'blue').set_title('Top 10 Highest Death Cases')

# %% [markdown]
# As at 30th August, 2022, Lagos has the highest death cases also due to its high population and number of confirmed cases and death cases. It was the first to record its first in Nigeria. It is began to be the hottest spot before spreading nationwide. Lagos is the busiest point of transit during international travels, hence the reason why most inbound passanges had the largest confirmed cases that might have led to deaths.
#
#
# The incidences thins out as we progress from Lagos, with Borno having the lowest death case. This may be attributed to the distance from the major hot spot, Lagos.

# %%
#Generate a line plot for the total daily confirmed, recovered and death cases in Nigeria

# %%
#extracting data for confirmed cases in Nigeria
confirmed_nig = JH_confirmed_global.groupby('Country/Region').sum().loc['Nigeria']
confirmed_nig
# Out:
# Lat             9.0820
# Long            8.6753
# 1/22/20         0.0000
# 1/23/20         0.0000
# 1/24/20         0.0000
#               ...
# 8/26/22    263322.0000
# 8/27/22    263407.0000
# 8/28/22    263407.0000
# 8/29/22    263407.0000
# 8/30/22    263526.0000
# Name: Nigeria, Length: 954, dtype: float64

# %%
TotalConfirmed=JH_Daily_Confirmed_Nigeriadf.sum(axis=0)

# %%
TotalRecoveries=JH_Daily_Recovery_Nigeriadf.sum(axis=0)

# %%
TotalDeaths = JH_Daily_DeathsNigeriadf.sum(axis=0)

# %%
TotalConfirmed
# Out:
# Confirmed Cases    137490811
# dtype: int64

# %%
TotalRecoveries
# Out:
# Recovered Cases    39492087
# dtype: int64

# %%
TotalDeaths
# Out:
# Death Cases    1799577
# dtype: int64

# %%
#Getting a dataframe for total daily cases
z = np.array([137490811, 39492087, 1799577])
df2 = pd.DataFrame(z, columns=['total'], index=["Confirmed Cases", "Recovered Cases", "Death Cases"])
df2
# Out:
#                      total
# Confirmed Cases  137490811
# Recovered Cases   39492087
# Death Cases        1799577

# %% [markdown]
# TODO E - Generate a line plot for the total daily confirmed, recovered and death cases in Nigeria

# %%
# plotting daily data for confirmed cases in Nigeria using seaborn's line plot
plt.figure(figsize = (10,5))
sns.lineplot(data = JH_Daily_Confirmed_Nigeriadf , x = 'Date', y = 'Confirmed Cases').set_title('Daily Total Confirmed Cases')
# Out:
# Text(0.5, 1.0, 'Daily Total Confirmed Cases')

# %% [markdown]
# There is apparent increase in daily confirmed cases are cummulative values, as at 30th August, 2022.

# %%
# plotting daily data for Recovered cases in Nigeria using seaborn's line plot
plt.figure(figsize = (10,5))
sns.lineplot(data = JH_Daily_Recovery_Nigeriadf , x = 'Date', y = 'Recovered Cases').set_title('Daily Total Recoveries')
# Out:
# Text(0.5, 1.0, 'Daily Total Recoveries')

# %% [markdown]
# Increased daily recovery cases were recorded with brief periods of unchangin records.
#
# These records again were cummulative values.
#
# No record of recovery in Nigeria was recorded from 2021-09 because only death cases were recorded as cummulative confirmed cases increased as time of data retrieval on 30th August, 2022.

# %%
# plotting daily data for death cases in Nigeria using a seaborn's line plot
plt.figure(figsize = (10,5))
sns.lineplot(data = JH_Daily_DeathsNigeriadf, x = 'Date', y = 'Death Cases').set_title('Daily Total Deaths')
# Out:
# Text(0.5, 1.0, 'Daily Total Deaths')

# %% [markdown]
# Record for daily total deaths were cummulatively increasing with intervals of unchanging records as at the time of data retrieval on 30th August, 2022.

# %% [markdown]
# # TODO F -
#
# >Determine the daily infection rate, you can use the Pandas diff method to find the derivate of the total cases.
# >Generate a line plot for the above

# %%
#Determine the daily infection rate, using the Pandas diff method to find the derivate of the total cases.
JH_Daily_Confirmed_Nigeriadf['Infection Rate'] = JH_Daily_Confirmed_Nigeriadf['Confirmed Cases'].diff()

# %% [markdown]
# # TODO J -
#
# >Provide more analyses by extending TODO G & H. Meaning, determine relationships between more features.
# >Provide a detailed summary of your findings.

# %%
#Checking if new data has been created
JH_Daily_Confirmed_Nigeriadf
# Out:
#           Date  Confirmed Cases  Infection Rate
# 0   2020-01-22                0             NaN
# 1   2020-01-23                0             0.0
# 2   2020-01-24                0             0.0
# 3   2020-01-25                0             0.0
# 4   2020-01-26                0             0.0
# ..         ...              ...             ...
# 947 2022-08-26           263322             0.0
# 948 2022-08-27           263407            85.0
# 949 2022-08-28           263407             0.0
# 950 2022-08-29           263407             0.0
# 951 2022-08-30           263526           119.0
#
# [952 rows x 3 columns]

# %%
# Generating a line plot for daily infection rate in Nigeria from global data
plt.figure(figsize = (20,10))
sns.lineplot(x = 'Date', y = 'Infection Rate', data = JH_Daily_Confirmed_Nigeriadf)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Infection Rate'>

# %% [markdown]
# # TODO G -
#
# >Calculate maximum infection rate for a day (Number of new cases)
# >Find the date

# %%
#Calculating maximum infection rate for a day (Number of new cases)
#Find the date
Highest_infection_rate=JH_Daily_Confirmed_Nigeriadf['Infection Rate'].max()

# %%
Highest_infection_rate
# Out:
# 6158.0

# %%
#Find the date
JH_Daily_Confirmed_Nigeriadf[JH_Daily_Confirmed_Nigeriadf['Infection Rate'] == 6158.0]
# Out:
#           Date  Confirmed Cases  Infection Rate
# 700 2021-12-22           231413          6158.0

# %%
#Calculating minimum infection rate for a day (Number of new cases)
Lowest_infection_rate=JH_Daily_Confirmed_Nigeriadf['Infection Rate'].min()
Lowest_infection_rate
# Out:
# -30.0

# %%
#Find the date for minimum infection rate
JH_Daily_Confirmed_Nigeriadf[JH_Daily_Confirmed_Nigeriadf['Infection Rate'] == -30.0]
# Out:
#           Date  Confirmed Cases  Infection Rate
# 812 2022-04-13           255633           -30.0

# %% [markdown]
# # TODO H - Determine the relationship between the external dataset and the NCDC COVID-19 dataset. Here you will generate a line plot of top 10 confirmed cases and the overall community vulnerability index on the same axis. From the graph, explain your observation.
# Steps
#
# >Combine the two dataset together on a common column(states)
# >Create a new dataframe for plotting. This DataFrame will contain top 10 states in terms of confirmed cases i.e sort by confirmed cases. Hint: Check out Pandas nlargest function. This tutorial can help out
# >Plot both variable on the same axis. Check out this tutorial

# %%
# Determining the relationship between the external dataset and the NCDC COVID-19 dataset. 
# Will generate and explain a line plot of top 10 confirmed cases and the overall community vulnerability index on the same axis.

# %%
covid_external.rename(columns = {'states': 'States Affected'}, inplace = True)

# %%
#Combine the two dataset together on a common column(states)
NCDC_external = ncdcdata_rn.merge(covid_external, on = 'States Affected', how = 'inner')

# %%
#Obtain top 10 Lab confirmed cases fro external data using df.nlargest()
Top10_NCDC_external = NCDC_external.nlargest(10, 'Number of Lab Confirmed Cases')

# %%
Top10_NCDC_external
# Out:
#    Unnamed: 0 States Affected  Number of Lab Confirmed Cases  \
# 0           0           Lagos                         103145
# 1           1             FCT                          29161
# 2           2          Rivers                          17755
# 3           3          Kaduna                          11487
# 4           4             Oyo                          10328
# 5           5         Plateau                          10309
# 6           6             Edo                           7821
# 7           7            Ogun                           5810
# 8           8           Delta                           5653
# 9           9            Kano                           5186
#
#    Number of Cases on Admission  Number of Cases Discharged  Number of Deaths  \
# 0                             2                      102372               771
# 1                           120                       28792               249
# 2                           180                       17420               155
# 3                            20                       11378                89
# 4                             2                       10124               202
# 5                            27                       10207                75
# 6                           102                        7398               321
# 7                            11                        5717                82
# 8                           371                        5170               112
# 9                            50                        5009               127
#
#           region  Population  Overall CCVI Index  Age  Epidemiological  \
# 0     South West    13992000                 0.0  0.1              1.0
# 1  North Central     4865000                 0.3  0.0              0.9
# 2    South South     7763000                 0.4  0.5              0.9
# 3     North West     9227000                 0.7  0.1              0.9
# 4     South West     8737000                 0.2  0.7              0.8
# 5  North Central     4766000                 0.4  0.5              0.4
# 6    South South     4705000                 0.1  0.9              0.8
# 7     South West     5878000                 0.3  0.6              0.7
# 8    South South     6303000                 0.4  0.6              0.7
# 9     North West    14726000                 0.6  0.2              0.1
#
#    Fragility  Health System  Population Density  Socio-Economic  \
# 0        0.3            0.1                 1.0             0.1
# 1        0.4            0.6                 0.9             0.6
# 2        0.6            0.6                 0.9             0.1
# 3        0.8            0.9                 0.4             0.6
# 4        0.2            0.8                 0.6             0.2
# 5        0.8            0.3                 0.3             0.5
# 6        0.1            0.1                 0.5             0.4
# 7        0.5            0.6                 0.6             0.0
# 8        0.2            1.0                 0.6             0.5
# 9        0.3            0.4                 0.8             0.8
#
#     Transport Availability  Acute IHR
# 0                      0.4       0.93
# 1                      0.2       0.79
# 2                      0.1       1.00
# 3                      0.4       0.86
# 4                      0.3       1.06
# 5                      0.3       0.93
# 6                      0.3       1.09
# 7                      0.2       1.07
# 8                      0.4       1.08
# 9                      0.5       0.87

# %%
# 2-axis plotting to establish relationship between overal CCVI index and Lab confirmed cases 
fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(1,1,1)
ax1.plot(Top10_NCDC_external['States Affected'], Top10_NCDC_external['Number of Lab Confirmed Cases'])
ax1.set_ylabel('No. of Cases (Lab Confirmed)')

ax2 = ax1.twinx()
ax2.plot(Top10_NCDC_external['States Affected'], Top10_NCDC_external['Overall CCVI Index'], 'r-')
ax2.set_ylabel('Overall CCVI Index', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')

# %% [markdown]
# General progression of relationsip between number of confirmed cases and OCCVI for the top 10 states shows an inverse correlation. Southern States like Lagos were not severely impacted by COVID-19 crisis. Northern States showed that they were worst hit by the effect of COVID-19.
#
# Lagos with the highest No of confirmed cases still has the lowest vulnerability index. Conversely however, Kaduna, Kano and Plateau with relatively lower confirmed cases showed higher overall CCVI index respectively, with Kano recording the overall lowest confirmed cases and Kaduna with the overall highest OCCVI. States like Rivers, Oyo, Edo, Ogun and Delta showed lower confirmed cases and corresponding OCCVI.
#
# This observation might suggest that Southern States like Lagos were not severely impacted by COVID-19 crisis due to some factors like education, infrastructure and stronger economy of which most northern states are challenged with.

# %%
#Further Analysis

# %%
# 2-axis plotting to establish relationship between overal CCVI index and Socio-Economic index
fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(1,1,1)
ax1.plot(Top10_NCDC_external['States Affected'], Top10_NCDC_external['Socio-Economic'])
ax1.set_ylabel('Socio-Economic')

ax2 = ax1.twinx()
ax2.plot(Top10_NCDC_external['States Affected'], Top10_NCDC_external['Overall CCVI Index'], 'g-')
ax2.set_ylabel('Overall CCVI Index', color='g')
for tl in ax2.get_yticklabels():
    tl.set_color('g')

# %% [markdown]
# Low Socio-economic index reflects the social and economic empowerments such as lower poverty rate, access to information, education and employment, higher index indicates high poverty, illiteracy e.t.c
#
# With the exception of Delta, most southern states have lower Socio-economic index than northern states with Lagos and Ogun showing the lowest.
#
# With Kaduna and Kano again with the highest OCCVI, Kaduna's lower Socio-economic index is the same as Lagos while Kano has the highest Socio-economic index.
#
# Lagos shows low Socio-economic index with also a correspondingly low overall OCCVI.
#
# Rivers had high Socio-economic index but high OCCVI index.
#
# Both indices are virtually the same for Oyo state, while Edo showed lower OCCVI with high OCCVI.
#
# Both indices are roughly the same for Delta and Plateau.

# %%
#2-axis plotting to establish relationship between overal CCVI index and Acute IHR Index.
fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(1,1,1)
ax1.plot(Top10_NCDC_external['States Affected'], Top10_NCDC_external['Acute IHR'])
ax1.set_ylabel('Acute IHR')

ax2 = ax1.twinx()
ax2.plot(Top10_NCDC_external['States Affected'], Top10_NCDC_external['Overall CCVI Index'], 'y-')
ax2.set_ylabel('Overall CCVI Index', color='y')
for tl in ax2.get_yticklabels():
    tl.set_color('y')

# %% [markdown]
# Inverse correlation between Overall CCVI index and Acute IHR were observed in all top 10 states.
#
# All Southern states have higher Acute IHR and corresponding low Overall CCVI, while northern states (Kaduna, Plataeu and Kano) showed lower Acute IHR and correspondingly higher Overall CCVI index.
#
# Plateau State apparently appears in between the situation with northern and southern states. Lagos has the lowest Overall CCVI with its corresponding high Acute IHR, while Kaduna has the highest Overall CCVI index with its corresponding Acute IHR index.
#
# Thsese observation suggests that the impact of covid crisis cannot be traced to Acute IHR alone.

# %%
#2-axis plotting to establish relationship between overal CCVI index and Fragility index.
fig = plt.figure(figsize = (10,5))
ax1 = fig.add_subplot(1,1,1)
ax1.plot(Top10_NCDC_external['States Affected'], Top10_NCDC_external['Fragility'])
ax1.set_ylabel('Fragility')

ax2 = ax1.twinx()
ax2.plot(Top10_NCDC_external['States Affected'], Top10_NCDC_external['Overall CCVI Index'], 'b-')
ax2.set_ylabel('Overall CCVI Index', color='b')
for tl in ax2.get_yticklabels():
    tl.set_color('b')

# %% [markdown]
# Fragility indices tend to correlate inversely with overall CCVI index. Subfactors considered for fragility index include: Population of concern sites, Food insecurity, Civil Unrest, e.t.c. Northern states (Kaduna, FCT, Plateau) tend to have high fragility score but only Kaduna and FCT show that their Overall CCVI index is traceable to their corresponding high fragility index. The same cannot be said about Kano and plateau.
#
# Southern states with comparatively lower fragility index (Edo having the lowest), have slightly higher corresponding Overall CCVI score except for Lagos which shows the overall low fragility score but slightly higher fragility score.
#
# Summarily, the direct correlation in only two northern states (Kaduna and FCT) demonstrates that vulnerability to the covid crisis is indeed tied to fragility scores, while the vulnerability may not be associated to fragility for the others in the top ten states.

# %% [markdown]
# TODO I - Determine the relationship between the external dataset and the NCDC COVID-19 dataset.
#
# >Here you will generate a regression plot between two variables to visualize the linear relationships - Confirmed Cases and Population Density. Hint: Check out Seaborn Regression Plot.
# >Provide a summary of your observation

# %% [markdown]
# # Determining the relationship between the external dataset and the NCDC COVID-19 dataset.
#
# #Generating a regression plot between two variables to visualize the linear relationships - Confirmed Cases and Population Density. Hint: Check out Seaborn Regression Plot.
#
# #Also will Provide a summary of observation

# %%
#Regression plot between Confirmed cases population density of top 10 states.
# regplot
plt.figure(figsize = (10,5))
ax = sns.regplot(x="Population Density", y="Number of Lab Confirmed Cases", data=Top10_NCDC_external).set_title('Confirmed Cases and Population Density for top 10 states')

# %% [markdown]
# For the top ten (10) highest confirmed cases, it is generally observed that only a few states there tend to have higher incidences of confirmed cases as population density tend to increase. However, many outliers (exception to this case) exists: There are three occurences which are above the common distribution value across states and there are five occurences which are below the common distribution value in states of various population densities.
#
# This shows that number of cases confirmed for those three ocuurences above the trendline are associated with higher number of confirmed cases and lower population densities. The five occurences demonstrates that lower records of confirmed cases are associated with higher popullation densities.

# %%
# Regression Plot for Lab confirmed cases vs population density for all states
plt.figure(figsize = (10,5))
ax = sns.regplot(x="Population Density", y="Number of Lab Confirmed Cases", data=NCDC_external).set_title('Confirmed Cases and Population Density for all States')

# %% [markdown]
# The general trend for all states indicates that lower record of Lab confirmed cases is associated with higher population densities across all states. The many outliers below the trend line indicates this.

# %%
# Further analysis on other indicators: Recovery rate
JH_Daily_Recovery_Nigeriadf['Recovery Rate'] = JH_Daily_Recovery_Nigeriadf['Recovered Cases'].diff()

# %%
# Further analysis on other indicators: Death rate
JH_Daily_DeathsNigeriadf['Death Rate'] = JH_Daily_DeathsNigeriadf['Death Cases'].diff()

# %%
# Further analysis on other indicators: lineplot of Recovery rate 
plt.figure(figsize = (20,10))
sns.lineplot(x = 'Date', y = 'Recovery Rate', data = JH_Daily_Recovery_Nigeriadf).set_title('Daily Recovery Rate in Nigeria')
# Out:
# Text(0.5, 1.0, 'Daily Recovery Rate in Nigeria')

# %% [markdown]
# The highest recorded rate of recovery of 11188.0 was made on 2020-08-04 while the lowest was -165208.0 on 2021-08-05.

# %%
JH_Daily_Recovery_Nigeriadf
# Out:
#           Date  Recovered Cases  Recovery Rate
# 0   2020-01-22                0            NaN
# 1   2020-01-23                0            0.0
# 2   2020-01-24                0            0.0
# 3   2020-01-25                0            0.0
# 4   2020-01-26                0            0.0
# ..         ...              ...            ...
# 947 2022-08-26                0            0.0
# 948 2022-08-27                0            0.0
# 949 2022-08-28                0            0.0
# 950 2022-08-29                0            0.0
# 951 2022-08-30                0            0.0
#
# [952 rows x 3 columns]

# %%
# Highest recovery rate
Highest_recovery_rate=JH_Daily_Recovery_Nigeriadf['Recovery Rate'].max()
Highest_recovery_rate
# Out:
# 11188.0

# %%
#Find the date
JH_Daily_Recovery_Nigeriadf[JH_Daily_Recovery_Nigeriadf['Recovery Rate'] == 11188.0]
# Out:
#           Date  Recovered Cases  Recovery Rate
# 195 2020-08-04            31851        11188.0

# %%
Lowest_recovery_rate=JH_Daily_Recovery_Nigeriadf['Recovery Rate'].min()
Lowest_recovery_rate
# Out:
# -165208.0

# %%
#Find the date

JH_Daily_Recovery_Nigeriadf[JH_Daily_Recovery_Nigeriadf['Recovery Rate'] == -165208.0]
# Out:
#           Date  Recovered Cases  Recovery Rate
# 561 2021-08-05                0      -165208.0

# %%
# Further analysis on other indicators: Seaborn's lineplot Death rate
plt.figure(figsize = (15,5))
sns.lineplot(x = 'Date', y = 'Death Rate', data = JH_Daily_DeathsNigeriadf).set_title('Daily Death Rate in Nigeria')
# Out:
# Text(0.5, 1.0, 'Daily Death Rate in Nigeria')

# %% [markdown]
# There was a spike in the death rate in Nigeria on 2021-08-29 with a record high of 93.0. The reason may be because of relaxed perventive measures with apparent ease of local restrictions. The lowest death rate of -4.0 was recorded on 2022-06-10 perhaps due to the success at global control the corona virus, especially in year 2022.

# %%
Highest_death_rate = JH_Daily_DeathsNigeriadf['Death Rate'].max()
Highest_death_rate
# Out:
# 93.0

# %%
#Find the date
JH_Daily_DeathsNigeriadf[JH_Daily_DeathsNigeriadf['Death Rate'] == 93.0]
# Out:
#           Date  Death Cases  Death Rate
# 585 2021-08-29         2454        93.0

# %%
Lowest_death_rate=JH_Daily_DeathsNigeriadf['Death Rate'].min()
Lowest_death_rate
# Out:
# -4.0

# %%
#Find the date
JH_Daily_DeathsNigeriadf[JH_Daily_DeathsNigeriadf['Death Rate'] ==-4.0]
# Out:
#           Date  Death Cases  Death Rate
# 870 2022-06-10         3144        -4.0

# %%
#Regression
plt.figure(figsize = (10,5))
ax = sns.regplot(x=NCDC_external["Age"], y=NCDC_external["Number of Lab Confirmed Cases"], data=NCDC_external).set_title('Age and infection Pattern in Nigeria')

# %% [markdown]
# The above plot displays the association between number of confirmed cases and age of populations. It can be infered from the plot that the occurences along or close to the trendline are higher confirmed cases with higher Age index scores. There are however lesser confirmed cases associated with lower age index.
#
# This shows that aged populace are more susceptible to Coronarvirus than the younger population.

# %%
plt.figure(figsize = (10,5))
ax = sns.regplot(x="Age", y="Number of Deaths", data=NCDC_external).set_title('Age and Mortality in States in Nigeria')

# %% [markdown]
# Apparently, the number of deaths tends to be more in the elderly population (more occurences tend to cluster close to the trendline at higher indices), even though many age categories are captured in lower covid related deaths.
# indices that can be traced to lower death are however associated with younger population.

# %%
# Bar plot for Mortality and Health Systems
plt.figure(figsize = (10,5))
ax = sns.barplot(x="Health System", y="Number of Deaths", data=NCDC_external).set_title('Mortality and Health System')

# %% [markdown]
# Health systems of a country may influence the overall health impact of coroner virus. According to Africa COVID-19 Community guiding principles, higher system indices show that health crisis mangagemnt are less effective and therefore there are chances that there will be lower number of discharged cases. Higher health system index score indicate weak health system.
#
# From the bar plots above, lower deaths are associated with various health system index score. Health System index of 0.1 (very low) was associatated with the highest number of deaths. With this relationship and high standard of deviation, it is therefore not clear whether health systems in states in Nigeria had any significant influence on the number of deaths recorded during the covid crisis

# %%
#Bar plot for Discharged cases and Health Systems
plt.figure(figsize = (10,5))
ax = sns.barplot(x="Health System", y="Number of Cases Discharged", data=NCDC_external).set_title('Discharged Cases and Health System')

# %% [markdown]
# Health systems of a country may influence the overall health impact of coroner virus. According to Africa COVID-19 Community guiding principles, higher system indices show that health crisis mangagemnt are less effective and therefore there are chances that there will be lower number of discharged cases.
#
# So far from the barplot, it is inconclusive to say that the health system of Nigeria influenced the number of covid discharged cases in Nigeria. This is further highlighted by the large error bars which indicates higher measure of dispersion from any possible trend.

# %%
#Plotting Health System in States
plt.figure(figsize = (8,12))
sns.barplot(x = NCDC_external['Health System'], y = NCDC_external['States Affected'], data = NCDC_external, color = 'green').set_title('Health System Index in States')
# Out:
# Text(0.5, 1.0, 'Health System Index in States')

# %% [markdown]
# The barplot above shows that health System index is diverse for states in Nigeria.

# %% [markdown]
# TODO L -
# Determine the effect of the Pandemic on the economy. To do this, you will compare the Real GDP value Pre-COVID-19 with Real GDP in 2020 (COVID-19 Period, especially Q2 2020)
# Steps
#
# >From the Real GDP Data, generate a barplot using the GDP values for each year & quarters. For example: On x-axis you will have year 2017 and the bars will be values of each quarters(Q1-Q4). You expected to have subplots of each quarters on one graph.
# >Hint: Use Pandas.melt to create your plot DataFrame
# >Set your quarter legend to lower left.
# >Using axhline, draw a horizontal line through the graph at the value of Q2 2020.
# >Write out your observation

# %%
#Determine the effect of the Pandemic on the economy. To do this, you will compare the Real GDP value Pre-COVID-19 with Real GDP in 2020 (COVID-19 Period, especially Q2 2020)
#From the Real GDP Data, generate a barplot using the GDP values for each year & quarters. For example: On x-axis you will have year 2017 and the bars will be values of each quarters(Q1-Q4). You expected to have subplots of each quarters on one graph.
#Hint: Use Pandas.melt to create your plot DataFrame

# %%
#Declaring the dtat set to be used
RealGDP
# Out:
#    Year           Q1           Q2           Q3           Q4
# 0  2014  15438679.50  16084622.31  17479127.58  18150356.45
# 1  2015  16050601.38  16463341.91  17976234.59  18533752.07
# 2  2016  15943714.54  16218542.41  17555441.69  18213537.29
# 3  2017  15797965.83  16334719.27  17760228.17  18598067.07
# 4  2018  16096654.19  16580508.07  18081342.10  19041437.59
# 5  2019  16434552.65  16931434.89  18494114.17  19530000.00
# 6  2020  16740000.00  15890000.00  17820000.00         0.00

# %%
#Restructuring the RealGDP dataframe for easy readability and accessibility
Q_RealGDP= pd.melt(RealGDP, id_vars=['Year'], var_name='Quarter', value_name='Amount in Billion(N)')

# %%
Q_RealGDP
# Out:
#     Year Quarter  Amount in Billion(N)
# 0   2014      Q1           15438679.50
# 1   2015      Q1           16050601.38
# 2   2016      Q1           15943714.54
# 3   2017      Q1           15797965.83
# 4   2018      Q1           16096654.19
# 5   2019      Q1           16434552.65
# 6   2020      Q1           16740000.00
# 7   2014      Q2           16084622.31
# 8   2015      Q2           16463341.91
# 9   2016      Q2           16218542.41
# 10  2017      Q2           16334719.27
# 11  2018      Q2           16580508.07
# 12  2019      Q2           16931434.89
# 13  2020      Q2           15890000.00
# 14  2014      Q3           17479127.58
# 15  2015      Q3           17976234.59
# 16  2016      Q3           17555441.69
# 17  2017      Q3           17760228.17
# 18  2018      Q3           18081342.10
# 19  2019      Q3           18494114.17
# 20  2020      Q3           17820000.00
# 21  2014      Q4           18150356.45
# 22  2015      Q4           18533752.07
# 23  2016      Q4           18213537.29
# 24  2017      Q4           18598067.07
# 25  2018      Q4           19041437.59
# 26  2019      Q4           19530000.00
# 27  2020      Q4                  0.00

# %%
# generating a seaborn's barplot using the GDP values for each year & quarters
plt.figure(figsize = (10,5))
sns.barplot(x = 'Year', y = 'Amount in Billion(N)',hue = 'Quarter', data =Q_RealGDP).set_title('Annual-Quaterly GDP')
plt.legend(loc = 'lower left')
plt.axhline(y =15890000.00, label ='Hline', color ='black')

# %% [markdown]
# The second quarter of 2020 (onset of impact of pandemic in Nigeria) was used to apply an axhline threashold and bench mark for comparison of dataset parameters.
#
#
# There is no record for the fourth quarter's GDP in 2020
#
#
# Economic activities during the fourth quarter was virtually grounded hence there is no record of GDP for fourth quater of 2020. This also means that 2020 has the lowest combined GDP in the years under review.
#
#
# The impact of covid 19 was huge on Nigeria's economy around the second quarter, in 2020, because that was when the highest cases of daily infection were recorded.
#
#
# The negative effects of covid on the population and the control measures enforced by the government affected productivity, all compared to other years included in the review.

# %%
Budget_data
# Out:
#          states  Initial_budget (Bn)  Revised_budget (Bn)
# 0          Abia               136.60               102.70
# 1       Adamawa               183.30               139.31
# 2     Akwa-Ibom               597.73               366.00
# 3       Anambra               137.10               112.80
# 4        Bauchi               167.20               128.00
# 5       Bayelsa               242.18               183.15
# 6         Benue               189.00               119.00
# 7         Borno               146.80               108.80
# 8   Cross River              1100.00               147.10
# 9         Delta               395.50               282.30
# 10       Ebonyi               178.40               131.80
# 11          Edo               179.20               128.80
# 12        Ekiti               124.50                91.10
# 13        Enugu               169.56               146.40
# 14        Gombe               130.83               107.40
# 15          Imo               197.60               108.30
# 16       Jigawa               152.92               124.00
# 17       Kaduna               259.25               223.60
# 18         Kano               200.00               138.00
# 19      Katsina               244.00               213.00
# 20        Kebbi               138.00                99.60
# 21         Kogi               176.00               102.00
# 22        Kwara               160.00               120.00
# 23        Lagos              1680.00               920.50
# 24     Nasarawa               108.40                62.96
# 25        Niger               155.00                98.00
# 26         Ogun               449.90               280.00
# 27         Ondo               187.80               151.40
# 28         Osun               119.60                82.20
# 29          Oyo               213.00               174.00
# 30      Plateau               177.30               122.00
# 31       Rivers               530.80               300.40
# 32       Sokoto               202.40               153.00
# 33       Taraba               215.00               150.50
# 34         Yobe               108.00                86.00
# 35      Zamfara               188.50               127.30
# 36          FCT               278.78               199.00

# %%
plt.figure(figsize = (8,12))
sns.barplot(y='states', x='Initial_budget (Bn)',data=Budget_data).set_title('Initial budget for states before COVID')
# Out:
# Text(0.5, 1.0, 'Initial budget for states before COVID')

# %%
Lagos had the highest initial bugdet before COVID
# Out:
#   Input In [191]
#     Lagos had the highest initial bugdet before COVID
#           ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize = (8,12))
sns.barplot(y='states', x='Revised_budget (Bn)',data=Budget_data).set_title('Revised budget for states during COVID')
# Out:
# Text(0.5, 1.0, 'Revised budget for states during COVID')

# %%
sns.jointplot(x='Initial_budget (Bn)',y='Revised_budget (Bn)',data=Budget_data)

# %%
Budget_data['Budget difference (%)'] = Budget_data[['Initial_budget (Bn)', 'Revised_budget (Bn)']].pct_change(axis=1)['Revised_budget (Bn)']*100

# %%
Budget_data
# Out:
#          states  Initial_budget (Bn)  Revised_budget (Bn)  \
# 0          Abia               136.60               102.70
# 1       Adamawa               183.30               139.31
# 2     Akwa-Ibom               597.73               366.00
# 3       Anambra               137.10               112.80
# 4        Bauchi               167.20               128.00
# 5       Bayelsa               242.18               183.15
# 6         Benue               189.00               119.00
# 7         Borno               146.80               108.80
# 8   Cross River              1100.00               147.10
# 9         Delta               395.50               282.30
# 10       Ebonyi               178.40               131.80
# 11          Edo               179.20               128.80
# 12        Ekiti               124.50                91.10
# 13        Enugu               169.56               146.40
# 14        Gombe               130.83               107.40
# 15          Imo               197.60               108.30
# 16       Jigawa               152.92               124.00
# 17       Kaduna               259.25               223.60
# 18         Kano               200.00               138.00
# 19      Katsina               244.00               213.00
# 20        Kebbi               138.00                99.60
# 21         Kogi               176.00               102.00
# 22        Kwara               160.00               120.00
# 23        Lagos              1680.00               920.50
# 24     Nasarawa               108.40                62.96
# 25        Niger               155.00                98.00
# 26         Ogun               449.90               280.00
# 27         Ondo               187.80               151.40
# 28         Osun               119.60                82.20
# 29          Oyo               213.00               174.00
# 30      Plateau               177.30               122.00
# 31       Rivers               530.80               300.40
# 32       Sokoto               202.40               153.00
# 33       Taraba               215.00               150.50
# 34         Yobe               108.00                86.00
# 35      Zamfara               188.50               127.30
# 36          FCT               278.78               199.00
#
#     Budget difference (%)
# 0              -24.816984
# 1              -23.998909
# 2              -38.768340
# 3              -17.724289
# 4              -23.444976
# 5              -24.374432
# 6              -37.037037
# 7              -25.885559
# 8              -86.627273
# 9              -28.621997
# 10             -26.121076
# 11             -28.125000
# 12             -26.827309
# 13             -13.658882
# 14             -17.908737
# 15             -45.192308
# 16             -18.911849
# 17             -13.751205
# 18             -31.000000
# 19             -12.704918
# 20             -27.826087
# 21             -42.045455
# 22             -25.000000
# 23             -45.208333
# 24             -41.918819
# 25             -36.774194
# 26             -37.763948
# 27             -19.382322
# 28             -31.270903
# 29             -18.309859
# 30             -31.190073
# 31             -43.406179
# 32             -24.407115
# 33             -30.000000
# 34             -20.370370
# 35             -32.466844
# 36             -28.617548

# %%
#Determining the minimum Budget difference
Budget_data['Budget difference (%)'].max()
# Out:
# -12.704918032786882

# %%
#Determining the Maximum Budget difference
Budget_data['Budget difference (%)'].min()
# Out:
# -86.62727272727273

# %%
#Extracting the State with minimum budget revision
Budget_data.loc[Budget_data['Budget difference (%)']==Budget_data['Budget difference (%)'].max()]
# Out:
#      states  Initial_budget (Bn)  Revised_budget (Bn)  Budget difference (%)
# 19  Katsina                244.0                213.0             -12.704918

# %%
#Extracting the state with the maximum budget revision
Budget_data.loc[Budget_data['Budget difference (%)']==Budget_data['Budget difference (%)'].min()]
# Out:
#         states  Initial_budget (Bn)  Revised_budget (Bn)  \
# 8  Cross River               1100.0                147.1
#
#    Budget difference (%)
# 8             -86.627273
